# %%
import sqlite3
conn = sqlite3.connect("storage/file_monitor.db")
cursor =conn.cursor()

cursor.execute("""
CREATE TABLE IF NOT EXISTS files (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    file_name TEXT NOT NULL
);
""")
conn.commit()

# %%
from langchain_community.document_loaders import PyPDFLoader

file_paths = [
    'storage/2022 M&I Shutdown closure report.pdf',
    'storage/FCC INDMAX OPERATING MANUAL 2020.pdf',
    'storage/FINAL DOCUMENT DATA BOOK.pdf'
]

pages = []

for file_path in file_paths:
    loader = PyPDFLoader(file_path)
    for page in loader.lazy_load():
        pages.append(page)

# %%
import getpass
from dotenv import load_dotenv
from config import get_config

key=get_config()

# %%
import os
os.environ["OPENAI_API_KEY"] = key['KEY']

from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-large")

# %%
import faiss
from langchain_community.docstore.in_memory import InMemoryDocstore
from langchain_community.vectorstores import FAISS

index = faiss.IndexFlatL2(len(embeddings.embed_query("hello world")))

vector_store = FAISS(
    embedding_function=embeddings,
    index=index,
    docstore=InMemoryDocstore(),
    index_to_docstore_id={},
)
batch_size = 100  # you can tune this depending on GPU/CPU RAM

for i in range(0, len(pages), batch_size):
    batch = pages[i:i + batch_size]
    vector_store.add_documents(batch)

# %%
index_dir = "faiss_indexes" 
vector_store= FAISS.load_local('faiss',embeddings,

# %%
data=vector_store.similarity_search('''The primary gas vents contain orifices that keep the gas film between the faces.
Ensure that they are installed before the initial compressor startup or after turnaround. Without those
orifices, the primary seal will fail. The location and elevation of those orifices are important compared
to the compressor shaft center. GP''')

# %%
from llm.bot import load_gpt_llm
from langgraph.checkpoint.memory import InMemorySaver
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage
from loging import setup_logger
from config import load_open_ai_api_config

config_values = load_open_ai_api_config()
key = config_values["api_key"]
logger = setup_logger('faiss_maker')
embeddings = OpenAIEmbeddings(model="text-embedding-3-large", api_key=key)

llm = load_gpt_llm()

# Define State
class ChatState(TypedDict):
    messages: Annotated[list, operator.add]
    context: str
    sources: list

# Node function
def retrieve_and_generate(state: ChatState):
    messages = state["messages"]
    last_message = messages[-1].content
    
    # Retrieve from FAISS
    index_dir = "faiss_indexes"
    vector_store = FAISS.load_local(index_dir, embeddings, allow_dangerous_deserialization=True)
    docs = vector_store.similarity_search(last_message, k=3)
    
    # Extract context and sources
    context = "\n\n".join([doc.page_content for doc in docs])
    sources = [doc.metadata.get('filename', 'Unknown') for doc in docs]
    unique_sources = list(set(sources))
    
    # Build prompt with history
    system_msg = SystemMessage(content="You are to generate the relevant answer based on the context for the input question")
    context_msg = SystemMessage(content=f"Context:\n{context}")
    
    # Prepare messages for LLM (include history)
    llm_messages = [system_msg, context_msg] + messages
    

    final_answer= llm.invoke(llm_messages)
    
    # Add sources to response
    response_with_sources = f"{final_answer.content}\n\n**Sources:** {', '.join(unique_sources)}"
    
    return {
        "messages": [AIMessage(content=response_with_sources)],
        "context": context,
        "sources": unique_sources
    }

# Build graph
workflow = StateGraph(ChatState)
workflow.add_node("rag_agent", retrieve_and_generate)
workflow.set_entry_point("rag_agent")
workflow.add_edge("rag_agent", END)

# Compile with memory
memory = InMemorySaver()
app = workflow.compile(checkpointer=memory)

# Usage function
def context_aware_chatbot_stream(question, thread_id="default"):
    config = {"configurable": {"thread_id": thread_id}}
    
    # Use stream_mode="messages" for token-by-token streaming
    for message_chunk, metadata in app.stream(
        {"messages": [HumanMessage(content=question)]}, 
        config,
        stream_mode="messages"  # ✅ This enables token streaming
    ):
        # Only yield content chunks (skip empty ones)
        if message_chunk.content:
            yield message_chunk.content


# # Streaming version
# def context_aware_chatbot_stream(question, thread_id="default"):
#     """
#     Streaming version - yields chunks
#     """
#     index_dir = "faiss_indexes"
#     vector_store = FAISS.load_local(index_dir, embeddings, allow_dangerous_deserialization=True)
#     docs = vector_store.similarity_search(question, k=3)
    
#     context = "\n\n".join([doc.page_content for doc in docs])
#     sources = [doc.metadata.get('filename', 'Unknown') for doc in docs]
#     unique_sources = list(set(sources))
    
#     # Get conversation history
#     config = {"configurable": {"thread_id": thread_id}}
#     state = app.get_state(config)
#     history_messages = state.values.get("messages", []) if state.values else []
    
#     # Build prompt  with history
#     system_msg = f"""You are to generate the relevant answer based on the context for the input question
    
# Context:
# {context}"""
    
#     messages = [SystemMessage(content=system_msg)] + history_messages + [HumanMessage(content=question)]
    
#     # Stream response
#     full_response = ""
#     for chunk in llm.stream(messages):
#         full_response += chunk.content
#         yield chunk.content
    
#     # Yield sources
#     sources_text = f"\n\n**Sources:** {', '.join(unique_sources)}"
#     yield sources_text
    
#     # Save to memory after streaming
#     app.update_state(
#         config,
#         {
#             "messages": [
#                 HumanMessage(content=question),
#                 AIMessage(content=full_response + sources_text)
#             ]
#         }
#     )

# %%
answer=context_aware_chatbot_stream("hello can you tell me about CRITICAL JOB: REVISIONING OF REMOSA VALVES ")

# %%
config = {"configurable": {"thread_id": "default"}}
a=app.invoke(
        {"messages": [HumanMessage(content="hello can you tell me about CRITICAL JOB: REVISIONING OF REMOSA VALVES ")]}, 
        config,

    )

# %%
a['messages'][-1].content
# Out:
# 'Here’s a concise overview of the CRITICAL JOB: REVISIONING OF REMOSA VALVES.\n\nWhat it was\n- A critical refurbishment/revisioning of REMOSA valves conducted during the IOCL Paradip Refinery M&I shutdown in 2022.\n- Carried out in the presence of the OEM, M/s REMOSA SRL.\n- A detailed OEM report was provided; the summary focuses on the eight valves touched and the spare parts replaced.\n\nValves touched and spares replaced\n1) Tag 23-LV-41 – Spent Catalyst Slide Valve\n   - Replaced: Orifice plate, packing gland, etc.\n2) Tag 23-TV-03 – Regenerated Catalyst Slide Valve\n   - Replaced: Orifice plate, disc, stem, packing gland, etc.\n3) Tag 23-XZV-42 – Diverter Valve\n   - Replaced: 36” SPWD gasket\n4) Tag 23-HV-17 – Double Disc Slide Valve\n   - Replaced: Stem, packing ring, bolts, lantern ring, etc.\n5) Tag 23-XV-2013 – PRT Flue gas Inlet Isolation Valve\n   - Remarks: No spare listed\n6) Tag 23-PV-96 – Flue gas to PRT inlet Butterfly valve\n   - Replaced: Gland packing, lantern ring, oil seal, etc.\n7) Tag 23-XV-14 – PRT inlet butterfly valve\n   - Replaced: Gland packing, lantern ring, oil seal, etc.\n8) Tag 23-XV-94 – PRT complete bypass butterfly\n   - Replaced: Gland packing, lantern ring, oil seal, etc.\n\nKey lessons learned\n- Have these tools/consumables ready in advance:\n  - Pneumatic impact wrench\n  - Plasma cutting machine with sufficient nozzles\n  - Adequate grousing electrodes\n- These are needed during removal of the orifice plate and related components.\n\nOther notes\n- The data block in the document includes a detailed instrument/valve specification template; the actionable items are the eight valves above and their associated spare parts.\n- A detailed OEM report exists with more granular details, verifications, and test data.\n\nIf you’d like, I can pull out more granular details (e.g., exact part numbers, serials, or test results) for a specific valve or summarize the OEM findings in a tighter format.\n\n**Sources:** 2022 M&I Shutdown closure report.pdf, FINAL DOCUMENT DATA BOOK.pdf'

# %%
app.get_state(config={"configurable": {"thread_id":"default"}})
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='hello can you tell me about CRITICAL JOB: REVISIONING OF REMOSA VALVES ', additional_kwargs={}, response_metadata={}), AIMessage(content='Here’s a concise summary of the CRITICAL JOB: REVISIONING OF REMOSA VALVES from the IOCL Paradip PDR M&I shutdown 2022 document you provided.\n\nWhat it was\n- A critical refurbishment/revisioning task of REMOSA valves conducted during the IOCL Paradip Refinery shutdown in 2022.\n- Performed in the presence of the OEM M/s REMOSA SRL.\n- A detailed report was provided by the OEM; the message here is the summarized tabulated data of the job and the components involved.\n\nValves and replacements (spares replaced)\n1) Tag 23-LV-41 – Spent Catalyst Slide Valve\n   - Replaced: Orifice plate, packing gland, etc.\n2) Tag 23-TV-03 – Regenerated Catalyst Slide Valve\n   - Replaced: Orifice plate, disc, stem, packing gland, etc.\n3) Tag 23-XZV-42 – Diverter Valve\n   - Replaced: 36” SPWD gasket\n4) Tag 23-HV-17 – Double Disc Slide Valve\n   - Replaced: Stem, packing ring, bolts, lantern ring, etc.\n5) Tag 23-XV-2013 – PRT Flue gas Inlet Isolation Valve\n   - Remarks: (no spare listed)\n6) Tag 23-PV-96 – Flue gas to PRT inlet Butterfly valve\n   - Replaced: Gland packing, lantern ring, oil seal, etc.\n7) Tag 23-XV-14 – PRT inlet butterfly valve\n   - Replaced: Gland packing, lantern ring, oil seal, etc.\n8) Tag 23-XV-94 – PRT complete bypass butterfly\n   - Replaced: Gland packing, lantern ring, oil seal, etc.\n\nLessons learnt\n- Essential tools and consumables to have ready beforehand:\n  - Pneumatic impact wrench\n  - Plasma cutting machine\n  - Sufficient quantity of nozzles and grousing electrodes\n- These are required during removal of the orifice plate and guide components.\n\nAdditional notes\n- The section indicates that the detailed OEM report exists and was shared, which would contain the full witnessed details, verifications, and perhaps test data for each valve.\n- The data block following the list appears to be a generic/structured valve specification template (likely related to the valves involved), but the key actionable items are the eight valves listed above and the observed replacements plus the stated lessons.\n\nIf you’d like, I can pull out more specific details for any particular valve (e.g., exact spare parts list, serials, or related test data) or summarize the OEM report findings in a more structured format.\n\n**Sources:** 2022 M&I Shutdown closure report.pdf, FINAL DOCUMENT DATA BOOK.pdf', additional_kwargs={}, response_metadata={}, id='d9eac0ad-0d0a-46b6-b094-f4aa1f2dd693'), HumanMessage(content='what was the previos answer about', additional_kwargs={}, response_metadata={}), AIMessage(content='It was a concise summary of the “CRITICAL JOB: REVISIONING OF REMOSA VALVES” from the IOCL Paradip PDR M&I shutdown 2022. Specifically, it described:\n\n- The task as a critical refurbishment/revisioning of REMOSA valves during the Paradip refinery shutdown, with OEM involvement (M/s REMOSA SRL).\n- The eight valves touched and the spare parts replaced for each (e.g., 23-LV-41, 23-TV-03, 23-XZV-42, etc.), plus notes where no spare was listed.\n- Lessons learned, mainly about essential tools and consumables needed for removing components.\n- A note that a detailed OEM report exists, and the sources of the information.\n\nIf you want, I can pull out details for a specific valve or summarize the OEM findings more granularly.\n\n**Sources:** FINAL DOCUMENT DATA BOOK.pdf', additional_kwargs={}, response_metadata={}, id='3bb69f57-8233-472f-9a34-893fce98588e')], 'context': 'P. 46\n\nP. 461\n\nP. 39', 'sources': ['FINAL DOCUMENT DATA BOOK.pdf']}, next=(), config={'configurable': {'thread_id': 'default', 'checkpoint_ns': '', 'checkpoint_id': '1f0ae7d5-9aa9-6271-8004-e3d12bf41fa2'}}, metadata={'source': 'loop', 'writes': {'rag_agent': {'messages': [AIMessage(content='It was a concise summary of the “CRITICAL JOB: REVISIONING OF REMOSA VA ...

# %%
for chunk in answer:
    print(chunk)
# Out:
# content='' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='Here' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='’s' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' a' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' concise' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' summary' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' of' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' the' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' “' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='CR' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ITICAL' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' JOB' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=':' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' REV' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ISION' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ING' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' OF' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' REM' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='OSA' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' VAL' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='VES' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='”' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' from' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' the' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' IO' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='CL' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Parad' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ip' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Refin' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ery' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' M' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='&I' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' shutdown' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' in' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='202' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='2' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=':\n\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' What' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' it' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' was' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' A' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' critical' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' maintenance' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' task' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' to' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' revision' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' (' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='over' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='haul' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' REM' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='OSA' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' valves' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='.\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Car' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ried' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' out' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' in' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' the' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' presence' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' of' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' the' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' original' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' equipment' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' manufacturer' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' (' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='OEM' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='),' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' M' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='/s' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' REM' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='OSA' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' SR' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='L' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='.\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' A' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' detailed' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' report' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' was' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' prepared' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' shared' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' by' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' the' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' OEM' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' with' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' a' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' tab' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ulated' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' summary' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' of' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' work' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' done' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' parts' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' replaced' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Scope' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' key' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' items' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Eight' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' valve' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' items' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' were' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' covered' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' with' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' tag' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' numbers' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' names' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=':\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='   ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='1' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='23' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-L' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='V' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='41' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' –' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Sp' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ent' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Catalyst' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Slide' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Valve' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='   ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='2' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='23' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-TV' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='03' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' –' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Reg' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='enerated' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Catalyst' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Slide' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Valve' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='   ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='3' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='23' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-X' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='Z' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='V' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='42' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' –' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Diver' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ter' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Valve' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' (' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='36' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='”' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' SP' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='WD' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' gasket' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='   ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='4' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='23' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-H' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='V' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='17' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' –' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Double' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Disc' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Slide' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Valve' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='   ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='5' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='23' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-X' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='V' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='201' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='3' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' –' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' P' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='RT' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Fl' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ue' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' gas' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' In' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='let' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Isolation' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Valve' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='   ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='6' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='23' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-P' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='V' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='96' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' –' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Fl' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ue' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' gas' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' to' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' P' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='RT' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' inlet' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Butterfly' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' valve' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='   ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='7' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='23' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-X' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='V' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='14' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' –' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' P' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='RT' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' inlet' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' butterfly' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' valve' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='   ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='8' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='23' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-X' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='V' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='94' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' –' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' P' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='RT' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' complete' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' bypass' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' butterfly' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Remarks' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' (' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='sp' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ares' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' replaced' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' included' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' items' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' such' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' as' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' or' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ifice' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' plates' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' discs' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' stems' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' packing' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' glands' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' lantern' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' rings' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' g' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='askets' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' oil' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' seals' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' related' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' components' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Not' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='able' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' details' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' The' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' OEM' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='’s' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' detailed' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' report' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' accompanied' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' the' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' summary' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' indicating' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' the' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' specific' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' components' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' replaced' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' or' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' refurbished' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' for' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' each' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' valve' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='.\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' The' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' replacement' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' items' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' indicate' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' a' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' mix' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' of' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' critical' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' wear' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' parts' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' (' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='disc' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' stem' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' packing' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' lantern' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' rings' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=')' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' g' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='askets' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='/se' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='als' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Lessons' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' learned' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Essential' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' tools' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' consum' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ables' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' should' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' be' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' available' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' before' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' starting' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=':\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='   ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Pne' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='umatic' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' impact' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' wrench' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='   ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Plasma' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' cutting' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' machine' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' with' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' an' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' adequate' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' set' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' of' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' no' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='zz' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='les' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' gou' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ging' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' electrodes' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' These' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' tools' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' were' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' specifically' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' highlighted' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' as' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' necessary' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' during' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' the' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' removal' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' of' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' or' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='ifice' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' plates' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' guides' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' suggesting' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' that' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' some' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' components' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' required' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' cutting' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' or' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' heavy' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' dis' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='assembly' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Overall' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' takeaway' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' -' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' This' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' was' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' a' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' planned' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' OEM' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-supported' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' overhaul' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' of' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' high' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-pr' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='iority' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' REM' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='OSA' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' valves' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' to' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' restore' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' reliability' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' performance' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' with' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' a' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' clear' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' list' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' of' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' parts' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' replaced' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' practical' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' tool' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' requirements' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' identified' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' to' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' ensure' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' smooth' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' execution' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='.\n\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='If' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' you' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='’d' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' like' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' I' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' can' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=':\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' List' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' the' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' replacements' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' per' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' valve' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' in' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' a' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' cleaner' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' breakdown' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=',' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' or' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='\n' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='-' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' Extract' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' and' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' summarize' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' any' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' specific' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' observations' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' or' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' recommendations' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' from' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' the' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' OEM' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content=' report' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='.' additional_kwargs={} response_metadata={} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='' additional_kwargs={} response_metadata={'finish_reason': 'stop', 'model_name': 'gpt-5-nano-2025-08-07'} id='run--39047bcb-291f-4ccc-afa7-acdc6255030d'
# content='Here’s a concise summary of the “CRITICAL JOB: REVISIONING OF REMOSA VALVES” from the IOCL Paradip Refinery M&I shutdown in 2022:\n\n- What it was\n  - A critical maintenance task to revision (overhaul) REMOSA valves.\n  - Carried out in the presence of the original equipment manufacturer (OEM), M/s REMOSA SRL.\n  - A detailed report was prepared and shared by the OEM, with a tabulated summary of work done and parts replaced.\n\n- Scope and key items\n  - Eight valve items were covered, with tag numbers and names:\n    1) 23-LV-41 – Spent Catalyst Slide Valve\n    2) 23-TV-03 – Regenerated Catalyst Slide Valve\n    3) 23-XZV-42 – Diverter Valve (36” SPWD gasket)\n    4) 23-HV-17 – Double Disc Slide Valve\n    5) 23-XV-2013 – PRT Flue gas Inlet Isolation Valve\n    6) 23-PV-96 – Flue gas to PRT inlet Butterfly valve\n    7) 23-XV-14 – PRT inlet butterfly valve\n    8) 23-XV-94 – PRT complete bypass butterfly\n  - Remarks (spares replaced) included items such as orifice plates, discs, stems, packing glands, lantern rings, gaskets, oil seals, and related components.\n\n- Notable details\n  - The OEM’s detailed report accompanied the summary, indicating the specific components replaced or refurbished for each valve.\n  - The replacement items indicate a mix of critical wear parts (disc, stem, packing, lantern rings) and gaskets/seals.\n\n- Lessons learned\n  - Essential tools and consumables should be available before starting:\n    - Pneumatic impact wrench\n    - Plasma cutting machine with an adequate set of nozzles and gouging electrodes\n  - These tools were specifically highlighted as necessary during the removal of orifice plates and guides, suggesting that some components required cutting or heavy disassembly.\n\n- Overall takeaway\n  - This was a planned, OEM-supported overhaul of high-priority REMOSA valves to restore reliability and performance, with a clear list of parts replaced and practical tool requirements identified to ensure smooth execution.\n\nIf you’d like, I can:\n- List the replacements per valve in a cleaner breakdown, or\n- Extract and summarize any specific observations or recommendations from the OEM report.\n\n**Sources:** 2022 M&I Shutdown closure report.pdf, FINAL DOCUMENT DATA BOOK.pdf' additional_kwargs={} response_metadata={} id='1fd43e8f-283a-4953-a320-08a2fd75420f'

# %%
answer
# Out:
# <generator object context_aware_chatbot_stream at 0x7f6ce3296340>

# %%
answer2=context_aware_chatbot_stream('what was the previos answer about')

# %%
for chunk in answer2:
    print(chunk)
# Out:
# It
#  was
#  a
#  concise
#  summary
#  of
#  the
#  “
# CR
# ITICAL
#  JOB
# :
#  REV
# ISION
# ING
#  OF
#  REM
# OSA
#  VAL
# VES
# ”
#  from
#  the
#  IO
# CL
#  Parad
# ip
#  P
# DR
#  M
# &I
#  shutdown
#
# 202
# 2
# .
#  Specifically
# ,
#  it
#  described
# :
#
#
# -
#  The
#  task
#  as
#  a
#  critical
#  refurbishment
# /re
# vision
# ing
#  of
#  REM
# OSA
#  valves
#  during
#  the
#  Parad
# ip
#  refinery
#  shutdown
# ,
#  with
#  OEM
#  involvement
#  (
# M
# /s
#  REM
# OSA
#  SR
# L
# ).
#
# -
#  The
#  eight
#  valves
#  touched
#  and
#  the
#  spare
#  parts
#  replaced
#  for
#  each
#  (
# e
# .g
# .,
#
# 23
# -L
# V
# -
# 41
# ,
#
# 23
# -TV
# -
# 03
# ,
#
# 23
# -X
# Z
# V
# -
# 42
# ,
#  etc
# .),
#  plus
#  notes
#  where
#  no
#  spare
#  was
#  listed
# .
#
# -
#  Lessons
#  learned
# ,
#  mainly
#  about
#  essential
#  tools
#  and
#  consum
# ables
#  needed
#  for
#  removing
#  components
# .
#
# -
#  A
#  note
#  that
#  a
#  detailed
#  OEM
#  report
#  exists
# ,
#  and
#  the
#  sources
#  of
#  the
#  information
# .
#
#
# If
#  you
#  want
# ,
#  I
#  can
#  pull
#  out
#  details
#  for
#  a
#  specific
#  valve
#  or
#  summarize
#  the
#  OEM
#  findings
#  more
#  granular
# ly
# .
# It was a concise summary of the “CRITICAL JOB: REVISIONING OF REMOSA VALVES” from the IOCL Paradip PDR M&I shutdown 2022. Specifically, it described:
#
# - The task as a critical refurbishment/revisioning of REMOSA valves during the Paradip refinery shutdown, with OEM involvement (M/s REMOSA SRL).
# - The eight valves touched and the spare parts replaced for each (e.g., 23-LV-41, 23-TV-03, 23-XZV-42, etc.), plus notes where no spare was listed.
# - Lessons learned, mainly about essential tools and consumables needed for removing components.
# - A note that a detailed OEM report exists, and the sources of the information.
#
# If you want, I can pull out details for a specific valve or summarize the OEM findings more granularly.
#
# **Sources:** FINAL DOCUMENT DATA BOOK.pdf
